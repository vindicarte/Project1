# %%
import plotly.figure_factory as ff
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import plotly.figure_factory as ff
#       2 import numpy as np
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'plotly'

# %%
us_county_df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/minoritymajority.csv")
tx_counties_df = us_county_df[us_county_df["STNAME"] == "Texas"]
tx_counties_df.head()
# Out:
#        FIPS STNAME          CTYNAME  TOT_POP  TOT_MALE  TOT_FEMALE  WA_MALE  \
# 1797  48001  Texas  Anderson County    58190     35504       22686    25289
# 1798  48003  Texas   Andrews County    16117      8120        7997     7652
# 1799  48005  Texas  Angelina County    87597     42830       44767    35196
# 1800  48007  Texas   Aransas County    23818     11799       12019    10993
# 1801  48009  Texas    Archer County     8735      4379        4356     4233
#
#       WA_FEMALE  NHWA_MALE  NHWA_FEMALE  NHWhite_Alone  Not_NHWhite_Alone  \
# 1797      18536      19446        15741          35187              23003
# 1798       7575       3525         3669           7194               8923
# 1799      36229      26489        28101          54590              33007
# 1800      11232       8103         8445          16548               7270
# 1801       4204       3890         3906           7796                939
#
# ...
